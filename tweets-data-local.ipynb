# %% [markdown]
# Import libraries

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# Load environment variables

# %%
SAMPLE = os.environ.get("SAMPLE", None)
show_columns = ["url", "content", "retweetCount"]

# %%
# Set the path to load the data from based on the value of the SAMPLE env variable
data_path = "data/farmers-protest-tweets-sample.json" if SAMPLE else "data/farmers-protest-tweets-2021-2-4.json"
# Load the data from the selected, note the lines=True as this is a newline delimited JSON file
data_df = pd.read_json(data_path, lines=True)
# Show a small sample of the data for reference
data_df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/ArjunSinghPanam/status/136...
# 1  https://twitter.com/PrdeepNain/status/13645062...
# 2  https://twitter.com/parmarmaninder/status/1364...
# 3  https://twitter.com/anmoldhaliwal/status/13645...
# 4  https://twitter.com/KotiaPreet/status/13645061...
#
#                        date  \
# 0 2021-02-24 09:23:35+00:00
# 1 2021-02-24 09:23:32+00:00
# 2 2021-02-24 09:23:22+00:00
# 3 2021-02-24 09:23:16+00:00
# 4 2021-02-24 09:23:10+00:00
#
#                                              content  \
# 0  The world progresses while the Indian police a...
# 1  #FarmersProtest \n#ModiIgnoringFarmersDeaths \...
# 2  ਪੈਟਰੋਲ ਦੀਆਂ ਕੀਮਤਾਂ ਨੂੰ ਮੱਦੇਨਜ਼ਰ ਰੱਖਦੇ ਹੋਏ \nਮੇ...
# 3  @ReallySwara @rohini_sgh watch full video here...
# 4  #KisanEktaMorcha #FarmersProtest #NoFarmersNoF...
#
#                                      renderedContent                   id  \
# 0  The world progresses while the Indian police a...  1364506249291784198
# 1  #FarmersProtest \n#ModiIgnoringFarmersDeaths \...  1364506237451313155
# 2  ਪੈਟਰੋਲ ਦੀਆਂ ਕੀਮਤਾਂ ਨੂੰ ਮੱਦੇਨਜ਼ਰ ਰੱਖਦੇ ਹੋਏ \nਮੇ...  1364506195453767680
# 3  @ReallySwara @rohini_sgh watch full video here...  1364506167226032128
# 4  #KisanEktaMorcha #FarmersProtest #NoFarmersNoF...  1364506144002088963
#
#                                                 user  \
# 0  {'username': 'ArjunSinghPanam', 'displayname':...
# 1  {'username': 'PrdeepNain', 'displayname': 'Pra...
# 2  {'username': 'parmarmaninder', 'displayname': ...
# 3  {'username': 'anmoldhaliwal', 'displayname': '...
# 4  {'username': 'KotiaPreet', 'displayname': 'Pre...
#
#                                             outlinks  \
# 0  [https://twitter.com/ravisinghka/status/136415...
# 1                                                 []
# 2                                                 []
# 3                     [https://youtu.be/-bUKumwq-J8]
# 4                                                 []
#
#                  tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0  [https://t.co/es3kn0IQAF]           0             0  ...           0
# 1                         []           0             0  ...           0
# 2                         []           0             0  ...           0
# 3  [https://t.co/wBPNdJdB0n]           0             0  ...           0
# 4                         []           0             0  ...           0
#
#         conversationId  lang  \
# 0  1364506249291784198    en
# 1  1364506237451313155    en
# 2  1364506195453767680    pa
# 3  1364350947099484160    en
# 4  1364506144002088963   und
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="https://mobile.twitter.com" rel="nofo...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                              sourceUrl          sourceLabel  \
# 0   http://twitter.com/download/iphone   Twitter for iPhone
# 1  http://twitter.com/download/android  Twitter for Android
# 2  http://twitter.com/download/android  Twitter for Android
# 3           https://mobile.twitter.com      Twitter Web App
# 4   http://twitter.com/download/iphone   Twitter for iPhone
#
#                                                media retweetedTweet  \
# 0                                               None            NaN
# 1  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...            NaN
# 2                                               None            NaN
# 3  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...            NaN
# 4  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
#
#                                          quotedTweet  \
# 0  {'url': 'https://twitter.com/RaviSinghKA/statu...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                       mentionedUsers
# 0  [{'username': 'narendramodi', 'displayname': '...
# 1  [{'username': 'Kisanektamorcha', 'displayname'...
# 2                                               None
# 3  [{'username': 'ReallySwara', 'displayname': 'S...
# 4                                               None
#
# [5 rows x 21 columns]

# %% [markdown]
# # Top retweets

# %%
data_df[data_df["retweetCount"] > 0][show_columns].sort_values("retweetCount", ascending=False).head(10)
# Out:
#                                                    url  \
# 797  https://twitter.com/hussain_hrw/status/1364463...
# 631  https://twitter.com/bhupenderc19/status/136447...
# 272  https://twitter.com/amaanbali/status/136449159...
# 331  https://twitter.com/Tractor2twitr/status/13644...
# 305  https://twitter.com/Khalsa_Aid/status/13644896...
# 418  https://twitter.com/bhupenderc19/status/136448...
# 746  https://twitter.com/GanveyManish/status/136446...
# 388  https://twitter.com/AkshayKhomane/status/13644...
# 309  https://twitter.com/JazbaatijHi9/status/136448...
# 598  https://twitter.com/ndtvvideos/status/13644738...
#
#                                                content  retweetCount
# 797  यह तस्वीरें टिकरी बॉर्डर की हैं जहाँ आस पास के...           121
# 631  "थम जाट नी थम हो गुलाम" \n\n#FarmersProtest मु...           102
# 272  Malkit Singh Ji (70) has passed away at Singhu...            69
# 331  Thank you @CoryBooker for standing up for farm...            53
# 305  #FarmersProtest \n\nGreat illustration of a pr...            50
# 418  बात ये है की हम सब एक परिवार हैं और चौधरी साहब...            39
# 746  #मोदी_है_तो_मुमकिन_है\nPlzz watch and read who...            39
# 388  Brave @SwetaSinghAT 2k Note GPS Chip Girl cove...            28
# 309  ਸਾਨੂੰ ਨੀ CLICKAN  ਪੈਂਦੀਆਂ, \nਸਾਨੂੰ ਹੁੰਦੇ ਨੀ VI...            25
# 598  'वही मंत्री आएं जिसके पास पावर हो', NDTV से बो...            25

# %% [markdown]
# Top users

# %%
data_df["username"] = data_df["user"].map(lambda x : x["username"])
data_df.groupby("username")["url"].count().sort_values(ascending=False).head(10)
# Out:
# username
# MaanDee08215437    57
# preetysaini321     43
# jas04361527        22
# AhluwaliaA2        17
# shells_n_petals    14
# salh_narinder      12
# DosanjhGreta       12
# rumsomal           12
# SADA_ANG_SANGE     10
# GurmVicky           8
# Name: url, dtype: int64

# %% [markdown]
# # Top dates

# %%
data_df["date_dd"] = data_df["date"].map(lambda x : x.date())

# %%
data_df.groupby("date_dd")["url"].count().sort_values(ascending=False).head(10)
# Out:
# date_dd
# 2021-02-24    1000
# Name: url, dtype: int64
